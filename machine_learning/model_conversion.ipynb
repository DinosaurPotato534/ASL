# %%
pip install tensorflowjs
# Out:
# ...
#   Using cached tensorflowjs-4.12.0-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached flax-0.7.2-py3-none-any.whl.metadata (10.0 kB)
# ...
#   Using cached importlib_resources-6.1.0-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached jax-0.4.13-py3-none-any.whl
# ...
#   Using cached jaxlib-0.4.13-cp38-cp38-macosx_10_14_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached tensorflow_decision_forests-1.5.0-cp38-cp38-macosx_10_15_x86_64.whl.metadata (4.9 kB)
# ...
#   Using cached tensorflow_hub-0.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached optax-0.1.7-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached orbax_checkpoint-0.2.3-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached rich-13.6.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached PyYAML-6.0.1-cp38-cp38-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached ml_dtypes-0.2.0-cp38-cp38-macosx_10_9_universal2.whl.metadata (20 kB)
# ...
#   Using cached protobuf-4.24.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (540 bytes)
# ...
